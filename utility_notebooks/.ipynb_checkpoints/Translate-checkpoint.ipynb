# %%
import deepl
import nbformat
import os

# %%
def translate_notebook(nb_file, translated_nb_file, auth_file):
	# fetch auth_key
	with open(auth_file, 'r') as f:
		auth_key = f.read().strip()
	translator = deepl.Translator(auth_key)
	# rewrite notebook markdowns, with a warning for markdowns not detected to be in EN
	ntbk = nbformat.read(nb_file, nbformat.NO_CONVERT)
	for cell in ntbk.cells:
		if cell.cell_type == 'markdown':
			result = translator.translate_text(cell.source, target_lang="FR")
			if result.detected_source_lang != 'EN':
				print(f"Detected source language {result.detected_source_lang}")
				print(f"Original: {cell.source}")
				print(f"Translation: {result.text}")
			cell.source = result.text
	nbformat.write(ntbk, translated_nb_file)

# %%
root = "/Users/thomas/Documents/Teaching/L1Descartes/science-des-données/utility_notebooks"

auth_file = os.path.join(root, "deepL_auth_key.txt")
nb_file = os.path.join(root, "notes_de_cours", "Séance2_CM.ipynb")
translated_nb_file = os.path.join(root, "notes_de_cours", "Séance2_CM_French.ipynb")
translate_notebook(nb_file, translated_nb_file, auth_file)
# Out:
# Detected source language FR
# Original: Crédits : ce cours est très fortement inspiré du cours data8 donné à UC Berkeley et dont les matériels sont généreusement mis à disposition publiquement sous licence Creative Commons avec attribution. Pour plus d'informations, consultez [http://www.data8.org/](http://www.data8.org/)
#
# TODOs
# - General intro
# - Traduction du code en pandas + seaborn
# - Traduction française avec deepL pour parties 2 et 3 du cours 1
# Translation: Crédits : ce cours est très fortement inspiré du cours data8 donné à UC Berkeley et dont les matériels sont généreusement mis à disposition publiquement sous licence Creative Commons avec attribution. Pour plus d'informations, consultez [http://www.data8.org/](http://www.data8.org/)
#
# TODOs
# - General intro
# - Traduction du code en pandas + seaborn
# - Traduction française avec deepL pour parties 2 et 3 du cours 1
# Detected source language FR
# Original: # Accueil et introduction générale du cours de science des données
# (durée estimée : 10min)
#
# TODO
# Translation: # Accueil et introduction générale du cours de science des données
# (durée estimée : 10min)
#
# TODO
# Detected source language FR
# Original: # Cours 1 : « faire parler les données »
# (durée estimée 1h20)
#
# Plan
# 1. Introduction (20min)
# 2. Manipulation et description des données (30min)
# 3. Visualisation des données (30min)
#
# Logique du cours
#
# - L'introduction illustre à travers un exemple que les données peuvent nous en dire beaucoup, si on sait comment les faire parler. Le but est de motiver la suite du cours, en introduisant les concepts informellement et sans rentrer dans les détails du code.
# - La deuxième partie se focalise sur les bases de la représentation et la manipulation de données avec la librairie pandas de python (création de table, accès par colonne et/ou par ligne, accès par condition, ajout de colonne, concatenation, jointures, groupement et application d'une fonction, chargement/sauvegarde dans un fichier) en en profitant pour introduire quelques statistiques descriptives (moyenne, variance, écart-type, étendue)
# - La troisième partie continue à mettre en œuvre les notions vues dans la deuxième partie et se concentre sur la représentation graphique des données à l'aide de la librairie seaborn de python (bar plots, histograms, scatter plots et line plots)
# Translation: # Cours 1 : « faire parler les données »
# (durée estimée 1h20)
#
# Plan
# 1. Introduction (20min)
# 2. Manipulation et description des données (30min)
# 3. Visualisation des données (30min)
#
# Logique du cours
#
# - L'introduction illustre à travers un exemple que les données peuvent nous en dire beaucoup, si on sait comment les faire parler. Le but est de motiver la suite du cours, en introduisant les concepts informellement et sans rentrer dans les détails du code.
# - La deuxième partie se focalise sur les bases de la représentation et la manipulation de données avec la librairie pandas de python (création de table, accès par colonne et/ou par ligne, accès par condition, ajout de colonne, concatenation, jointures, groupement et application d'une fonction, chargement/sauvegarde dans un fichier) en en profitant pour introduire quelques statistiques descriptives (moyenne, variance, écart-type, étendue)
# - La troisième partie continue à mettre en œuvre les notions vues dans la deuxième partie et se concentre sur la représentation graphique des données à l'aide de la librairie seaborn de python (bar plots, histograms, scatter plots et line plots)
# Detected source language FR
# Original: (Image générée avec DALL.E 3)
# Translation: (Image générée avec DALL.E 3)
# Detected source language FR
# Original: ## 1. Introduction : exemple des textes de romans classiques
# (durée estimée 20min)
#
# Plan
#
# - Tracer les classiques
# - Personnages littéraires
# - Nombres de caractères
#
# L'introduction illustre à travers un exemple que les données peuvent nous en dire beaucoup, si on sait comment les faire parler. Le but est de motiver la suite du cours, en introduisant les concepts informellement et sans rentrer dans les détails du code.
# Translation: ## 1. Introduction : exemple des textes de romans classiques
# (durée estimée 20min)
#
# Plan
#
# - Tracer les classiques
# - Personnages littéraires
# - Nombres de caractères
#
# L'introduction illustre à travers un exemple que les données peuvent nous en dire beaucoup, si on sait comment les faire parler. Le but est de motiver la suite du cours, en introduisant les concepts informellement et sans rentrer dans les détails du code.
# Detected source language FR
# Original: ### Tracer les classiques
#
# Dans cet exemple, nous allons explorer les statistiques de deux romans classiques : *Les aventures de Huckleberry Finn* de Mark Twain et *Little Women* de Louisa May Alcott (dont le titre de la traduction française est *Les quatres filles du docteur March*). Un ordinateur peut lire le texte de n'importe quel livre très rapidement. Les livres publiés avant 1923 sont actuellement dans le *domaine public*, ce qui signifie que tout le monde a le droit de copier ou d'utiliser le texte de quelque manière que ce soit. Le [Projet Gutenberg] (http://www.gutenberg.org/) est un site web qui publie des livres du domaine public en ligne. En utilisant Python, nous pouvons charger le texte de ces livres directement depuis le web.
#
# Cet exemple a pour but d'illustrer certains des grands thèmes de ce cours. Ne vous inquiétez pas si les détails du programme n'ont pas encore de sens. Concentrez-vous plutôt sur l'interprétation des images générées ci-dessous. Les sections suivantes du texte décriront la plupart des caractéristiques du langage de programmation Python utilisé ci-dessous.
#
# Tout d'abord, nous lisons le texte des deux livres en listes de chapitres, appelées `huck_finn_chapters` et `little_women_chapters`. En Python, un nom ne peut pas contenir d'espace, et nous utiliserons donc souvent un trait de soulignement `_` à la place d'un espace. Les `=` dans les lignes ci-dessous donnent un nom à gauche au résultat d'un calcul décrit à droite. Un *localisateur de ressources uniformes* ou *URL* est une adresse sur Internet pour un contenu ; dans ce cas, le texte d'un livre. Le symbole `#` commence un commentaire, qui est ignoré par l'ordinateur mais utile pour les personnes qui lisent le code.
# Translation: ### Tracer les classiques
#
# Dans cet exemple, nous allons explorer les statistiques de deux romans classiques : *Les aventures de Huckleberry Finn* de Mark Twain et *Little Women* de Louisa May Alcott (dont le titre de la traduction française est *Les quatres filles du docteur March*). Un ordinateur peut lire le texte de n'importe quel livre très rapidement. Les livres publiés avant 1923 sont actuellement dans le *domaine public*, ce qui signifie que tout le monde a le droit de copier ou d'utiliser le texte de quelque manière que ce soit. Le [Projet Gutenberg] (http://www.gutenberg.org/) est un site web qui publie des livres du domaine public en ligne. En utilisant Python, nous pouvons charger le texte de ces livres directement depuis le web.
#
# Cet exemple a pour but d'illustrer certains des grands thèmes de ce cours. Ne vous inquiétez pas si les détails du programme n'ont pas encore de sens. Concentrez-vous plutôt sur l'interprétation des images générées ci-dessous. Les sections suivantes du texte décriront la plupart des caractéristiques du langage de programmation Python utilisé ci-dessous.
#
# Tout d'abord, nous lisons le texte des deux livres en listes de chapitres, appelées `huck_finn_chapters` et `little_women_chapters`. En Python, un nom ne peut pas contenir d'espace, et nous utiliserons donc souvent un trait de soulignement `_` à la place d'un espace. Les `=` dans les lignes ci-dessous donnent un nom à gauche au résultat d'un calcul décrit à droite. Un *localisateur de ressources uniformes* ou *URL* est une adresse sur Internet pour un contenu ; dans ce cas, le texte d'un livre. Le symbole `#` commence un commentaire, qui est ignoré par l'ordinateur mais utile pour les personnes qui lisent le code.
# Detected source language FR
# Original: Bien qu'un ordinateur ne puisse pas comprendre le texte d'un livre, il peut nous donner un aperçu de la structure du texte. Le nom `huck_finn_chapters` est actuellement lié à une liste de tous les chapitres du livre. Nous pouvons les placer dans un tableau pour voir comment commence chaque chapitre.
# Translation: Bien qu'un ordinateur ne puisse pas comprendre le texte d'un livre, il peut nous donner un aperçu de la structure du texte. Le nom `huck_finn_chapters` est actuellement lié à une liste de tous les chapitres du livre. Nous pouvons les placer dans un tableau pour voir comment commence chaque chapitre.
# Detected source language FR
# Original: Chaque chapitre commence par un numéro de chapitre en chiffres romains, suivi de la première phrase du chapitre. Le Projet Gutenberg a imprimé le premier mot de chaque chapitre en majuscules.
# Translation: Chaque chapitre commence par un numéro de chapitre en chiffres romains, suivi de la première phrase du chapitre. Le Projet Gutenberg a imprimé le premier mot de chaque chapitre en majuscules.
# Detected source language FR
# Original: ### Personnages littéraires
#
# Les Aventures de Huckleberry Finn décrivent le voyage de Huck et Jim le long du Mississippi. Tom Sawyer les rejoint vers la fin, alors que l'action s'intensifie. Après avoir chargé le texte, nous pouvons rapidement visualiser combien de fois ces personnages ont été mentionnés dans chaque chapitre.
# Translation: ### Personnages littéraires
#
# Les Aventures de Huckleberry Finn décrivent le voyage de Huck et Jim le long du Mississippi. Tom Sawyer les rejoint vers la fin, alors que l'action s'intensifie. Après avoir chargé le texte, nous pouvons rapidement visualiser combien de fois ces personnages ont été mentionnés dans chaque chapitre.
# Detected source language FR
# Original: Dans le graphique ci-dessus, l'axe horizontal indique les numéros de chapitre et l'axe vertical le nombre de fois où chaque personnage a été mentionné jusqu'à ce chapitre inclus.
#
# Vous pouvez constater que Jim est un personnage central par le grand nombre de fois où son nom apparaît. Remarquez que Tom est à peine mentionné pendant la majeure partie du livre, jusqu'à ce qu'il arrive et rejoigne Huck et Jim, après le chapitre 30. Sa courbe et celle de Jim montent en flèche à ce moment-là, car l'action les impliquant tous les deux s'intensifie. Quant à Huck, son nom n'apparaît pratiquement pas, car il est le narrateur.
# Translation: Dans le graphique ci-dessus, l'axe horizontal indique les numéros de chapitre et l'axe vertical le nombre de fois où chaque personnage a été mentionné jusqu'à ce chapitre inclus.
#
# Vous pouvez constater que Jim est un personnage central par le grand nombre de fois où son nom apparaît. Remarquez que Tom est à peine mentionné pendant la majeure partie du livre, jusqu'à ce qu'il arrive et rejoigne Huck et Jim, après le chapitre 30. Sa courbe et celle de Jim montent en flèche à ce moment-là, car l'action les impliquant tous les deux s'intensifie. Quant à Huck, son nom n'apparaît pratiquement pas, car il est le narrateur.
# Detected source language FR
# Original: Le livre *Little Women* raconte l'histoire de quatre sœurs qui grandissent ensemble pendant la guerre civile. Dans ce livre, les numéros de chapitre sont écrits en toutes lettres et les titres de chapitre sont écrits en majuscules.
# Translation: Le livre *Little Women* raconte l'histoire de quatre sœurs qui grandissent ensemble pendant la guerre civile. Dans ce livre, les numéros de chapitre sont écrits en toutes lettres et les titres de chapitre sont écrits en majuscules.
# Detected source language FR
# Original: Nous pouvons suivre les mentions des personnages principaux pour en savoir plus sur l'intrigue de ce livre. La protagoniste Jo interagit régulièrement avec ses sœurs Meg, Beth et Amy, jusqu'au chapitre 27 où elle déménage seule à New York.
# Translation: Nous pouvons suivre les mentions des personnages principaux pour en savoir plus sur l'intrigue de ce livre. La protagoniste Jo interagit régulièrement avec ses sœurs Meg, Beth et Amy, jusqu'au chapitre 27 où elle déménage seule à New York.
# Detected source language FR
# Original: Laurie est un jeune homme qui épouse l'une des filles à la fin. Essayez de deviner laquelle en observant attentivement le graphique ci-dessus.
# Translation: Laurie est un jeune homme qui épouse l'une des filles à la fin. Essayez de deviner laquelle en observant attentivement le graphique ci-dessus.
# Detected source language FR
# Original: ### Nombres de caractères
#
# Dans certaines situations, les relations que nous observons entre différentes variables nous permettent de faire des prédictions. Nous allons explorer dans ce cours comment faire des prédictions précises à partir d'informations incomplètes et nous développerons des méthodes pour combiner plusieurs sources d'informations incertaines afin de prendre des décisions.
#
# Pour illustrer la visualisation d'informations provenant de sources multiples, utilisons d'abord l'ordinateur pour obtenir des informations qu'il serait fastidieux d'obtenir à la main. Dans le contexte des romans, le mot « caractère » signifie un symbole imprimé tel qu'une lettre, un chiffre ou un symbole de ponctuation. Ici, nous demandons à l'ordinateur de compter le nombre de caractères et le nombre de points dans chaque chapitre de *Huckleberry Finn* et de *Little Women*.
# Translation: ### Nombres de caractères
#
# Dans certaines situations, les relations que nous observons entre différentes variables nous permettent de faire des prédictions. Nous allons explorer dans ce cours comment faire des prédictions précises à partir d'informations incomplètes et nous développerons des méthodes pour combiner plusieurs sources d'informations incertaines afin de prendre des décisions.
#
# Pour illustrer la visualisation d'informations provenant de sources multiples, utilisons d'abord l'ordinateur pour obtenir des informations qu'il serait fastidieux d'obtenir à la main. Dans le contexte des romans, le mot « caractère » signifie un symbole imprimé tel qu'une lettre, un chiffre ou un symbole de ponctuation. Ici, nous demandons à l'ordinateur de compter le nombre de caractères et le nombre de points dans chaque chapitre de *Huckleberry Finn* et de *Little Women*.
# Detected source language FR
# Original: Voici les données pour *Huckleberry Finn*. Chaque ligne du tableau correspond à un chapitre du roman et indique le nombre de caractères ainsi que le nombre de points dans le chapitre. Il n'est pas surprenant de constater qu'en général les chapitres comportant moins de caractères ont également tendance à comporter moins de points : plus le chapitre est court, moins il y a de phrases, et vice versa. Cette relation n'est toutefois pas entièrement prévisible, car les phrases sont de longueur variable et peuvent comporter d'autres signes de ponctuation, tels que des points d'interrogation.
# Translation: Voici les données pour *Huckleberry Finn*. Chaque ligne du tableau correspond à un chapitre du roman et indique le nombre de caractères ainsi que le nombre de points dans le chapitre. Il n'est pas surprenant de constater qu'en général les chapitres comportant moins de caractères ont également tendance à comporter moins de points : plus le chapitre est court, moins il y a de phrases, et vice versa. Cette relation n'est toutefois pas entièrement prévisible, car les phrases sont de longueur variable et peuvent comporter d'autres signes de ponctuation, tels que des points d'interrogation.
# Detected source language FR
# Original: Vous pouvez constater que les chapitres de *Little Women* sont en général plus longs que ceux de *Huckleberry Finn*. Voyons si ces deux variables simples - la longueur et le nombre de points dans chaque chapitre - peuvent nous en dire plus sur les deux livres. Une façon d'y parvenir est de représenter les deux ensembles de données sur les mêmes axes.
#
# Dans le graphique ci-dessous, un point correspond à chaque chapitre de chaque livre. Les points bleus correspondent à *Huckleberry Finn* et les points dorés à *Little Women*. L'axe horizontal représente le nombre de périodes et l'axe vertical le nombre de personnages.
# Translation: Vous pouvez constater que les chapitres de *Little Women* sont en général plus longs que ceux de *Huckleberry Finn*. Voyons si ces deux variables simples - la longueur et le nombre de points dans chaque chapitre - peuvent nous en dire plus sur les deux livres. Une façon d'y parvenir est de représenter les deux ensembles de données sur les mêmes axes.
#
# Dans le graphique ci-dessous, un point correspond à chaque chapitre de chaque livre. Les points bleus correspondent à *Huckleberry Finn* et les points dorés à *Little Women*. L'axe horizontal représente le nombre de périodes et l'axe vertical le nombre de personnages.
# Detected source language FR
# Original: Le graphique nous montre que de nombreux chapitres de *Little Women*, mais pas tous, sont plus longs que ceux de *Huckleberry Finn*, comme nous l'avions observé en regardant simplement les chiffres. Mais il nous montre aussi quelque chose de plus. Remarquez que les points bleus sont grossièrement regroupés autour d'une ligne droite, tout comme les points jaunes. De plus, il semble que les deux couleurs de points puissent être regroupées autour de la même ligne droite.
# Translation: Le graphique nous montre que de nombreux chapitres de *Little Women*, mais pas tous, sont plus longs que ceux de *Huckleberry Finn*, comme nous l'avions observé en regardant simplement les chiffres. Mais il nous montre aussi quelque chose de plus. Remarquez que les points bleus sont grossièrement regroupés autour d'une ligne droite, tout comme les points jaunes. De plus, il semble que les deux couleurs de points puissent être regroupées autour de la même ligne droite.
# Detected source language FR
# Original: Maintenant, regardez tous les chapitres qui contiennent environ 100 points finaux. Le graphique montre que ces chapitres contiennent environ 10 000 à 15 000 caractères, en gros. Cela représente environ 100 à 150 caractères par point final.
#
# En effet, il ressort de l'analyse de l'intrigue qu'en moyenne, les deux livres ont tendance à contenir entre 100 et 150 caractère par point final, à titre d'estimation très approximative. Peut-être ces deux grands romans du XIXe siècle annonçaient-ils quelque chose qui nous est si familier aujourd'hui : la limite de 140 caractères de X (ex-Twitter) ?
# Translation: Maintenant, regardez tous les chapitres qui contiennent environ 100 points finaux. Le graphique montre que ces chapitres contiennent environ 10 000 à 15 000 caractères, en gros. Cela représente environ 100 à 150 caractères par point final.
#
# En effet, il ressort de l'analyse de l'intrigue qu'en moyenne, les deux livres ont tendance à contenir entre 100 et 150 caractère par point final, à titre d'estimation très approximative. Peut-être ces deux grands romans du XIXe siècle annonçaient-ils quelque chose qui nous est si familier aujourd'hui : la limite de 140 caractères de X (ex-Twitter) ?
# Detected source language FR
# Original: ## 2. Manipulation et description des données
# (durée estimée 30min)
# Translation: ## 2. Manipulation et description des données
# (durée estimée 30min)
# Detected source language FR
# Original: La deuxième partie se focalise sur les bases de la représentation et la manipulation de données avec la librairie pandas de python (création de table, accès par colonne et/ou par ligne, accès par condition, ajout/suppression de colonne, tri, concatenation, jointures, groupement et application d'une fonction, chargement/sauvegarde dans un fichier) en en profitant pour introduire quelques statistiques descriptives (moyenne, variance, écart-type, étendue)
# Translation: La deuxième partie se focalise sur les bases de la représentation et la manipulation de données avec la librairie pandas de python (création de table, accès par colonne et/ou par ligne, accès par condition, ajout/suppression de colonne, tri, concatenation, jointures, groupement et application d'une fonction, chargement/sauvegarde dans un fichier) en en profitant pour introduire quelques statistiques descriptives (moyenne, variance, écart-type, étendue)
# Detected source language NB
# Original: #### Sorting Rows
# Translation: #### Tri des lignes
# Detected source language NL
# Original: You can also specify the negation of any of these conditions, by using `.not_` before the condition:
#
# | **Predicate**              | Description                              |
# |----------------------------|------------------------------------------|
# | `are.not_equal_to(Z)`      | Not equal to `Z`                         |
# | `are.not_above(x)`         | Not above `x`                            |
# Translation: Vous pouvez également spécifier la négation de n'importe laquelle de ces conditions, en utilisant `.not_` devant la condition :
#
# | Les conditions d'accès à la base de données sont les suivantes : - **Prédicat** | Description
# |----------------------------|------------------------------------------|
# | `are.not_equal_to(Z)` | Non égal à `Z` | `are.not_abal_to(Z)` | `are.not_abal_to(Z)
# | `are.not_above(x)` | Non supérieur à `x` |
# Detected source language FR
# Original: ## 3. Visualisation des données
# (durée estimée 30min)
# Translation: ## 3. Visualisation des données
# (durée estimée 30min)
# Detected source language FR
# Original: La troisième partie continue à mettre en œuvre les notions vues dans la deuxième partie et se concentre sur la représentation graphique des données à l'aide de la librairie seaborn de python (bar plots, histograms, scatter plots et line plots)
# Translation: La troisième partie continue à mettre en œuvre les notions vues dans la deuxième partie et se concentre sur la représentation graphique des données à l'aide de la librairie seaborn de python (bar plots, histograms, scatter plots et line plots)
